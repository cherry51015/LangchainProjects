# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq

groq_api_key=os.getenv("GROQ_API_KEY")

llm=ChatGroq(groq_api_key=groq_api_key,model_name='llama-3.1-8b-instant')

llm

# %%
os.environ['HF_TOKEN']=os.getenv("HUGGINGFACE_API")
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
from langchain_vectorstores import Chroma
from langchain_community.document_loaders import WebBaseLoader
from langchain_core.prompts import ChatPromptTemplate
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain_vectorstores import Chroma
#       2 from langchain_community.document_loaders import WebBaseLoader
#       3 from langchain_core.prompts import ChatPromptTemplate
#
# ModuleNotFoundError: No module named 'langchain_vectorstores'

# %%
# 1. Load, chunk and index the contents of the blog to create a retriever.
#ekkada anni tuples lo untai and class pakkana _ untadhi and path pakkana , kooda undaali
import bs4
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader(web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),bs_kwargs=
                     dict(parse_only=bs4.SoupStrainer(class_=('post_content','post_title','post_header'))))
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/'}, page_content='')]
